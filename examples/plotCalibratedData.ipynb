# %%
from extra_geom import AGIPD_1MGeometry
from cxiapi import cxiData
import matplotlib.pyplot as plt
import h5py

# %%
cxi = cxiData('./bg.cxi')
cxi.setGeom('./detector.geom')

# %%
ROI_value = [[400,900],[300, 800]]
cxi.plot(1, ROI_value=ROI_value,vmin=100,vmax=200)

# %%
ROI_value = [[400,900],[300, 800]]
cxi.plot(1, ROI_value=ROI_value,vmin=100,vmax=200)
